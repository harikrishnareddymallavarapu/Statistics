# %% [markdown]
# <a href="https://colab.research.google.com/github/harikrishnareddymallavarapu/Statistics/blob/master/Data_Summarizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Categorical Data
- Frequency Tables
- Distributions

# %% [markdown]
# ![image.png=50x50](data:image/png;base64,...)

# %% [markdown]
# Single Categorical Variable - Pie Chart, Bar Chart
#
# https://oli.cmu.edu/jcourse/workbook/activity/page?context=729ed2280a0001dc583efff419a4274f

# %% [markdown]
# Quantitative Variable - Histogram, Stem Plot, Bar Plot
#
# **Interpreting Histogram**
#
# Overall Pattern:
# 1. Shape - Skewness, Peakedness
# 2. Center
# 3. Spread
#
# Deviations From Pattern:
# 1. Outliers
